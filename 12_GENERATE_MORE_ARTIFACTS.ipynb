# %%
import mne
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
channel_mapping = {
    'EEG FP1-REF': 'Fp1', 'EEG FP2-REF': 'Fp2',
    'EEG F3-REF': 'F3', 'EEG F4-REF': 'F4',
    'EEG C3-REF': 'C3', 'EEG C4-REF': 'C4',
    'EEG P3-REF': 'P3', 'EEG P4-REF': 'P4',
    'EEG O1-REF': 'O1', 'EEG O2-REF': 'O2',
    'EEG F7-REF': 'F7', 'EEG F8-REF': 'F8',
    'EEG T3-REF': 'T3', 'EEG T4-REF': 'T4',
    'EEG T5-REF': 'T5', 'EEG T6-REF': 'T6',
    'EEG FZ-REF': 'Fz', 'EEG CZ-REF': 'Cz',
    'EEG PZ-REF': 'Pz'
}

# %%
def convertDF2MNE(sub, sfreq):
    """
    Convierte un DataFrame de datos EEG en un objeto MNE Epochs.

    Parameters:
    - sub (pd.DataFrame): DataFrame con los datos EEG.
    - sfreq (float): Frecuencia de muestreo de los datos.

    Returns:
    - numpy.ndarray: Datos de epochs en formato (n_epochs, n_channels, n_samples).
    """
    info = mne.create_info(list(sub.columns), ch_types=['eeg'] * len(sub.columns), sfreq=sfreq)
    info.set_montage('standard_1020')
    data = mne.io.RawArray(sub.T, info)
    data.set_eeg_reference()
    # data.filter(l_freq=1, h_freq=30)
    epochs = mne.make_fixed_length_epochs(data, duration=3, overlap=2)
    return epochs.get_data()

# %%
def extract_dataframes(edf_file, annotations_file, artifact):
    """
    Extrae segmentos de datos EEG correspondientes a un tipo específico de anotación.

    Parameters:
    - edf_file (str): Ruta al archivo EDF.
    - annotations_file (str): Ruta al archivo de anotaciones CSV.
    - artifact (str): Tipo de anotación a extraer (e.g., 'musc').

    Returns:
    - numpy.ndarray: Datos de epochs en formato (n_epochs, n_channels, n_samples), o None si no se encuentra el artifact.
    """
    try:
        raw = mne.io.read_raw_edf(edf_file, preload=True, verbose='ERROR')
        
        channels_to_keep = [ch for ch in raw.ch_names if ch in channel_mapping]
        raw.pick(channels_to_keep)
        raw.rename_channels(channel_mapping)
        
        annotations_df = pd.read_csv(annotations_file, comment='#')
        
        annotation_mapping = {ch.split()[1]: new_name for ch, new_name in channel_mapping.items()}
        
        def map_annotation_channel(channel):
            try:
                ch1, ch2 = channel.split('-')
                mapped_ch1 = annotation_mapping.get(ch1, ch1)
                mapped_ch2 = annotation_mapping.get(ch2, ch2)
                return f"{mapped_ch1}-{mapped_ch2}"
            except ValueError:
                return channel
        
        if 'channel' not in annotations_df.columns:
            raise KeyError("La columna 'channel' no se encontró en el archivo de anotaciones.")
        
        annotations_df['channel'] = annotations_df['channel'].map(map_annotation_channel)
        
        valid_channels = [f"{ch1}-{ch2}" for ch1 in annotation_mapping.values() for ch2 in annotation_mapping.values()]
        annotations_df = annotations_df[annotations_df['channel'].isin(valid_channels)]
        
        annotations = mne.Annotations(
            onset=annotations_df['start_time'].values,
            duration=(annotations_df['stop_time'] - annotations_df['start_time']).values,
            description=annotations_df['label'].values
        )
        
        raw.set_annotations(annotations)
        
        target_annotations = raw.annotations[raw.annotations.description == artifact]
        
        if len(target_annotations) == 0:
            print(f"No se encontraron anotaciones para el artifact '{artifact}' en el archivo {edf_file}.")
            return None
        
        segments = []
        sfreq = raw.info['sfreq']
        
        for onset, duration in zip(target_annotations.onset, target_annotations.duration):
            tmin = onset
            tmax = onset + duration
            start_sample = int(tmin * sfreq)
            end_sample = int(tmax * sfreq)
            data, times = raw[:, start_sample:end_sample]
            df_segment = pd.DataFrame(data.T, columns=raw.ch_names)
            segments.append(df_segment)
        
        if not segments:
            print(f"No se encontraron segmentos para las anotaciones '{artifact}'.")
            return None
        
        df_artifact = pd.concat(segments, ignore_index=True)
        
        epochs_data = convertDF2MNE(df_artifact, sfreq)
        
        return epochs_data
    except Exception as e:
        print(f"Error procesando el archivo {edf_file} para el artifact '{artifact}': {e}")
        return None

# %%
def find_matching_edf_csv_files(directory):
    edf_files = set()
    csv_files = set()

    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.edf'):
                edf_files.add(os.path.splitext(file)[0])
            elif file.endswith('.csv'):
                csv_files.add(os.path.splitext(file)[0])

    matching_files = edf_files.intersection(csv_files)

    matching_edf = [os.path.join(directory, f"{name}.edf") for name in matching_files]
    matching_csv = [os.path.join(directory, f"{name}.csv") for name in matching_files]

    return matching_edf, matching_csv

# %%
def process_and_save_scaleograms(edf_file, annotations_file, artifacts, output_dir='./scaleogram'):
    """
    Procesa las anotaciones especificadas, aplica CWT usando ssqueezepy y guarda los resultados como archivos .npy.

    Parameters:
    - edf_file (str): Ruta al archivo EDF.
    - annotations_file (str): Ruta al archivo de anotaciones CSV.
    - artifacts (dict): Diccionario con tipos de anotaciones y sus etiquetas (e.g., {'eyem_musc': 0, 'musc_elec': 1}).
    - output_dir (str): Directorio base para guardar los archivos .npy.

    Returns:
    - pd.DataFrame: DataFrame con las rutas de los archivos .npy y sus etiquetas.
    """
    labels = []
    paths = []
    
    os.makedirs(output_dir, exist_ok=True)
    
    for artifact, label in artifacts.items():
        print(f"Procesando anotación: {artifact} con etiqueta: {label}")
        
        try:
            data = extract_dataframes(edf_file, annotations_file, artifact)
        except Exception as e:
            print(f"Error al procesar '{artifact}': {e}")
            continue
        
        for trial_idx, trial_data in enumerate(data):
            scaleograms = []
            
            for channel_idx, channel_data in enumerate(trial_data):
                Wx, scales = cwt(channel_data, 'morlet')
                Wx = np.abs(Wx)
                scaleograms.append(Wx)
            
            scaleograms = np.array(scaleograms)
            
            label_name = 'df_eyem_musc' if label == 0 else 'df_musc_elec'
            label_dir = os.path.join(output_dir, f'{label_name}')
            os.makedirs(label_dir, exist_ok=True)
            
            file_name = f'trial_{trial_idx}.npy'
            file_path = os.path.join(label_dir, file_name)
            
            np.save(file_path, scaleograms)
            
            paths.append(file_path)
            labels.append(label)
    
    df_scale = pd.DataFrame({'path': paths, 'label': labels})
    
    return df_scale

# %%
directory = 'v3.0.1/edf/01_tcp_ar/'

matching_edf_files, matching_csv_files = find_matching_edf_csv_files(directory)

artifacts = {
    'musc': 0,
    'eyem_musc': 1,
    'elec': 2,
    'chew': 3
}

print("Archivos EDF y CSV coincidentes:")
for edf_file, csv_file in zip(matching_edf_files, matching_csv_files):
    print(f"EDF: {edf_file}, CSV: {csv_file}")
    
    df_musc = extract_dataframes(edf_file, csv_file, 'musc')
    if df_musc is not None:
        print(f"Forma del array 'df_musc': {df_musc.shape}")
    else:
        print(f"No se pudo extraer 'musc' del archivo {edf_file}.")
    
    df_eyem_musc = extract_dataframes(edf_file, csv_file, 'eyem_musc')
    if df_eyem_musc is not None:
        print(f"Forma del array 'df_eyem_musc': {df_eyem_musc.shape}")
    else:
        print(f"No se pudo extraer 'eyem_musc' del archivo {edf_file}.")

    df_elec = extract_dataframes(edf_file, csv_file, 'elec')
    if df_elec is not None:
        print(f"Forma del array 'df_elec': {df_elec.shape}")
    else:
        print(f"No se pudo extraer 'elec' del archivo {df_elec}.")

    df_chew = extract_dataframes(edf_file, csv_file, 'chew')
    if df_chew is not None:
        print(f"Forma del array 'df_chew': {df_chew.shape}")
    else:
        print(f"No se pudo extraer 'chew' del archivo {df_chew}.")

    df_scale = process_and_save_scaleograms(edf_file, annotations_file, artifacts, output_dir='./scaleogram_output')

# %%
import os
import mne
import pandas as pd
import numpy as np
from ssqueezepy import cwt
import matplotlib.pyplot as plt

# Mapeo de canales
channel_mapping = {
    'EEG FP1-REF': 'Fp1', 'EEG FP2-REF': 'Fp2',
    'EEG F3-REF': 'F3', 'EEG F4-REF': 'F4',
    'EEG C3-REF': 'C3', 'EEG C4-REF': 'C4',
    'EEG P3-REF': 'P3', 'EEG P4-REF': 'P4',
    'EEG O1-REF': 'O1', 'EEG O2-REF': 'O2',
    'EEG F7-REF': 'F7', 'EEG F8-REF': 'F8',
    'EEG T3-REF': 'T3', 'EEG T4-REF': 'T4',
    'EEG T5-REF': 'T5', 'EEG T6-REF': 'T6',
    'EEG FZ-REF': 'Fz', 'EEG CZ-REF': 'Cz',
    'EEG PZ-REF': 'Pz'
}

def convertDF2MNE(sub, sfreq):
    """
    Convierte un DataFrame de datos EEG en un objeto MNE Epochs.

    Parameters:
    - sub (pd.DataFrame): DataFrame con los datos EEG.
    - sfreq (float): Frecuencia de muestreo de los datos.

    Returns:
    - numpy.ndarray: Datos de epochs en formato (n_epochs, n_channels, n_samples).
    """
    info = mne.create_info(list(sub.columns), ch_types=['eeg'] * len(sub.columns), sfreq=sfreq)
    info.set_montage('standard_1020')
    data = mne.io.RawArray(sub.T, info)
    data.set_eeg_reference()
    # data.filter(l_freq=1, h_freq=30)  # Puedes descomentar para aplicar filtrado
    epochs = mne.make_fixed_length_epochs(data, duration=3, overlap=2)
    return epochs.get_data()

def extract_dataframes(edf_file, annotations_file, artifact):
    """
    Extrae segmentos de datos EEG correspondientes a un tipo específico de anotación.

    Parameters:
    - edf_file (str): Ruta al archivo EDF.
    - annotations_file (str): Ruta al archivo de anotaciones CSV.
    - artifact (str): Tipo de anotación a extraer (e.g., 'musc').

    Returns:
    - numpy.ndarray: Datos de epochs en formato (n_epochs, n_channels, n_samples), o None si no se encuentra el artifact.
    """
    try:
        # Cargar datos crudos
        raw = mne.io.read_raw_edf(edf_file, preload=True, verbose='ERROR')
        
        # Seleccionar y renombrar canales
        channels_to_keep = [ch for ch in raw.ch_names if ch in channel_mapping]
        raw.pick_channels(channels_to_keep)
        raw.rename_channels(channel_mapping)
        
        # Cargar anotaciones
        annotations_df = pd.read_csv(annotations_file, comment='#')
        
        # Crear mapeo de canales para anotaciones
        annotation_mapping = {ch.split()[1]: new_name for ch, new_name in channel_mapping.items()}
        
        # Definir la función de mapeo dentro del ámbito de la función
        def map_annotation_channel(channel):
            try:
                ch1, ch2 = channel.split('-')
                mapped_ch1 = annotation_mapping.get(ch1, ch1)
                mapped_ch2 = annotation_mapping.get(ch2, ch2)
                return f"{mapped_ch1}-{mapped_ch2}"
            except ValueError:
                return channel
        
        # Aplicar el mapeo a la columna 'channel'
        if 'channel' not in annotations_df.columns:
            raise KeyError("La columna 'channel' no se encontró en el archivo de anotaciones.")
        
        annotations_df['channel'] = annotations_df['channel'].map(map_annotation_channel)
        
        # Filtrar anotaciones válidas
        valid_channels = [f"{ch1}-{ch2}" for ch1 in annotation_mapping.values() for ch2 in annotation_mapping.values()]
        annotations_df = annotations_df[annotations_df['channel'].isin(valid_channels)]
        
        # Crear objeto Annotations de MNE
        annotations = mne.Annotations(
            onset=annotations_df['start_time'].values,
            duration=(annotations_df['stop_time'] - annotations_df['start_time']).values,
            description=annotations_df['label'].values
        )
        
        # Asignar anotaciones a los datos crudos
        raw.set_annotations(annotations)
        
        # Filtrar solo las anotaciones del tipo especificado
        target_annotations = raw.annotations[raw.annotations.description == artifact]
        
        if len(target_annotations) == 0:
            print(f"No se encontraron anotaciones para el artifact '{artifact}' en el archivo {edf_file}.")
            return None
        
        segments = []
        sfreq = raw.info['sfreq']
        
        for onset, duration in zip(target_annotations.onset, target_annotations.duration):
            tmin = onset
            tmax = onset + duration
            start_sample = int(tmin * sfreq)
            end_sample = int(tmax * sfreq)
            data, times = raw[:, start_sample:end_sample]
            df_segment = pd.DataFrame(data.T, columns=raw.ch_names)
            segments.append(df_segment)
        
        if not segments:
            print(f"No se encontraron segmentos para las anotaciones '{artifact}'.")
            return None
        
        # Concatenar todos los segmentos en un solo DataFrame
        df_artifact = pd.concat(segments, ignore_index=True)
        
        # Convertir el DataFrame a datos MNE Epochs
        epochs_data = convertDF2MNE(df_artifact, sfreq)
        
        return epochs_data
    except Exception as e:
        print(f"Error procesando el archivo {edf_file} para el artifact '{artifact}': {e}")
        return None

def find_matching_edf_csv_files(directory):
    """
    Encuentra archivos .edf y .csv que tengan el mismo nombre base en un directorio dado.

    Parameters:
    - directory (str): Ruta al directorio a buscar.

    Returns:
    - tuple: Listas de rutas completas para archivos .edf y .csv que coinciden.
    """
    edf_files = {}
    csv_files = {}

    # Recorre el directorio para identificar archivos .edf y .csv
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.edf'):
                name = os.path.splitext(file)[0]
                edf_files[name] = os.path.join(root, file)
            elif file.endswith('.csv'):
                name = os.path.splitext(file)[0]
                csv_files[name] = os.path.join(root, file)

    # Encuentra los nombres que están en ambos conjuntos
    matching_names = set(edf_files.keys()).intersection(csv_files.keys())

    # Crear listas de archivos .edf y .csv con los mismos nombres
    matching_edf = [edf_files[name] for name in matching_names]
    matching_csv = [csv_files[name] for name in matching_names]

    return matching_edf, matching_csv

def process_and_save_scaleograms(edf_file, annotations_file, artifacts, output_dir='./scaleogram_output', max_trials=100):
    """
    Procesa las anotaciones especificadas, aplica CWT usando ssqueezepy y guarda los resultados como archivos .npy.

    Parameters:
    - edf_file (str): Ruta al archivo EDF.
    - annotations_file (str): Ruta al archivo de anotaciones CSV.
    - artifacts (dict): Diccionario con tipos de anotaciones y sus etiquetas (e.g., {'eyem_musc': 0, 'musc_elec': 1}).
    - output_dir (str): Directorio base para guardar los archivos .npy.
    - max_trials (int): Número máximo de trials a generar por artefacto.

    Returns:
    - pd.DataFrame: DataFrame con las rutas de los archivos .npy y sus etiquetas.
    """
    labels = []
    paths = []
    
    # Asegurar que el directorio base exista
    os.makedirs(output_dir, exist_ok=True)
    
    for artifact, label in artifacts.items():
        print(f"Procesando anotación: {artifact} con etiqueta: {label}")
        
        # Extraer datos para la anotación actual
        try:
            data = extract_dataframes(edf_file, annotations_file, artifact)
        except Exception as e:
            print(f"Error al procesar '{artifact}': {e}")
            continue
        
        if data is None:
            print(f"No se pudo extraer datos para el artifact '{artifact}' en el archivo {edf_file}.")
            continue
        
        num_trials = data.shape[0]
        if num_trials > max_trials:
            print(f"Se encontraron {num_trials} trials para '{artifact}'. Seleccionando los primeros {max_trials}.")
            data = data[:max_trials]
        else:
            print(f"Se encontraron {num_trials} trials para '{artifact}'.")
        
        # Aplicar CWT y guardar archivos .npy
        for trial_idx, trial_data in enumerate(data):  # data tiene forma (trials, channels, samples)
            # Inicializar lista para almacenar los scaleograms de cada canal
            scaleograms = []
            
            for channel_idx, channel_data in enumerate(trial_data):
                # Aplicar CWT con la onda Morlet
                Wx, scales = cwt(channel_data, 'morlet')  # Puedes ajustar 'scales' si lo deseas
                Wx = np.abs(Wx)
                scaleograms.append(Wx)
            
            # Convertir la lista de scaleograms a un array 3D (channels, frequencies, time)
            scaleograms = np.array(scaleograms)  # Forma: (channels, frequencies, time)
            
            # Definir la ruta para guardar el archivo .npy
            label_dir = os.path.join(output_dir, f'label_{label}_{artifact}')
            os.makedirs(label_dir, exist_ok=True)
            
            # Nombre único para el archivo
            file_name = f'trial_{trial_idx}.npy'
            file_path = os.path.join(label_dir, file_name)
            
            # Guardar el scaleogram
            np.save(file_path, scaleograms)
            
            # Añadir la ruta y la etiqueta a las listas
            paths.append(file_path)
            labels.append(label)
        
        print(f"Se han guardado {min(num_trials, max_trials)} trials para el artifact '{artifact}'.\n")
    
    # Crear el DataFrame final
    df_scale = pd.DataFrame({'path': paths, 'label': labels})
    
    return df_scale

def main():
    # Ruta de la carpeta a buscar
    directory = 'v3.0.1/edf/01_tcp_ar/'
    
    # Obtener los archivos coincidentes
    matching_edf_files, matching_csv_files = find_matching_edf_csv_files(directory)
    
    if not matching_edf_files:
        print("No se encontraron archivos .edf y .csv coincidentes en el directorio especificado.")
        return
    
    # Definir los artefactos y sus etiquetas
    artifacts = {
        'musc': 0,
        'eyem_musc': 1,
        'elec': 2,
        'chew': 3
    }
    
    # Lista para almacenar los DataFrames de scaleograms de todos los archivos
    all_scale_dfs = []
    
    # Imprimir los resultados emparejados y extraer datos
    print("Archivos EDF y CSV coincidentes:")
    for edf_file, csv_file in zip(matching_edf_files, matching_csv_files):
        print(f"EDF: {edf_file}, CSV: {csv_file}")
        
        # Procesar y guardar los scaleograms
        df_scale = process_and_save_scaleograms(
            edf_file, 
            csv_file, 
            artifacts, 
            output_dir='./scaleogram_output', 
            max_trials=100  # Limitar a 100 trials por artefacto
        )
        
        if df_scale is not None and not df_scale.empty:
            all_scale_dfs.append(df_scale)
            # Mostrar las primeras filas del DataFrame resultante
            print(df_scale.head())
        else:
            print(f"No se generaron scaleograms para el archivo {edf_file}.\n")
    
    # Concatenar todos los DataFrames en uno solo
    if all_scale_dfs:
        final_df = pd.concat(all_scale_dfs, ignore_index=True)
        # Guardar el DataFrame final a un archivo CSV si lo deseas
        final_df.to_csv('scaleograms_labels.csv', index=False)
        print("Proceso completado. DataFrame final guardado en 'scaleograms_labels.csv'.")
    else:
        print("No se generaron scaleograms para ninguno de los archivos.")

if __name__ == "__main__":
    main()
# Out:
# Archivos EDF y CSV coincidentes:
# EDF: v3.0.1/edf/01_tcp_ar/aaaaanrc_s004_t006.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaanrc_s004_t006.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=395444
#     Range : 0 ... 395443 =      0.000 ...  1544.699 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1542 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1542 events and 768 original time points ...
# 0 bad epochs dropped
# Se encontraron 1542 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaanrc_s004_t006.edf.
# No se pudo extraer datos para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaanrc_s004_t006.edf.
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'elec' en el archivo v3.0.1/edf/01_tcp_ar/aaaaanrc_s004_t006.edf.
# No se pudo extraer datos para el artifact 'elec' en el archivo v3.0.1/edf/01_tcp_ar/aaaaanrc_s004_t006.edf.
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaanrc_s004_t006.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaanrc_s004_t006.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaaayg_s002_t001.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaaayg_s002_t001.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=442176
#     Range : 0 ... 442175 =      0.000 ...  1105.438 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1103 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1103 events and 1200 original time points ...
# 0 bad epochs dropped
# Se encontraron 1103 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaayg_s002_t001.edf.
# No se pudo extraer datos para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaayg_s002_t001.edf.
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'elec' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaayg_s002_t001.edf.
# No se pudo extraer datos para el artifact 'elec' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaayg_s002_t001.edf.
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaayg_s002_t001.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaayg_s002_t001.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaaenq_s004_t000.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaaenq_s004_t000.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaenq_s004_t000.edf.
# No se pudo extraer datos para el artifact 'musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaenq_s004_t000.edf.
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaenq_s004_t000.edf.
# No se pudo extraer datos para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaenq_s004_t000.edf.
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=233604
#     Range : 0 ... 233603 =      0.000 ...   934.412 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 932 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 932 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 932 trials para 'elec'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaenq_s004_t000.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaenq_s004_t000.edf.
#                                            path  label
# 0  ./scaleogram_output\label_2_elec\trial_0.npy      2
# 1  ./scaleogram_output\label_2_elec\trial_1.npy      2
# 2  ./scaleogram_output\label_2_elec\trial_2.npy      2
# 3  ./scaleogram_output\label_2_elec\trial_3.npy      2
# 4  ./scaleogram_output\label_2_elec\trial_4.npy      2
# EDF: v3.0.1/edf/01_tcp_ar/aaaaakbz_s002_t000.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaakbz_s002_t000.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=165760
#     Range : 0 ... 165759 =      0.000 ...   663.036 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 661 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 661 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 661 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=259844
#     Range : 0 ... 259843 =      0.000 ...  1039.372 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1037 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1037 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 1037 trials para 'eyem_musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'eyem_musc'.
#
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=819683
#     Range : 0 ... 819682 =      0.000 ...  3278.728 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 3276 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 3276 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 3276 trials para 'elec'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaakbz_s002_t000.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaakbz_s002_t000.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaakeq_s002_t000.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaakeq_s002_t000.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=33579
#     Range : 0 ... 33578 =      0.000 ...   134.312 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 132 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 132 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 132 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaakeq_s002_t000.edf.
# No se pudo extraer datos para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaakeq_s002_t000.edf.
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=26201
#     Range : 0 ... 26200 =      0.000 ...   104.800 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 102 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 102 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 102 trials para 'elec'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaakeq_s002_t000.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaakeq_s002_t000.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaammu_s001_t001.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaammu_s001_t001.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=51571
#     Range : 0 ... 51570 =      0.000 ...   206.280 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 204 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 204 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 204 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=9286
#     Range : 0 ... 9285 =      0.000 ...    37.140 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 35 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 35 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 35 trials para 'eyem_musc'.
# Se han guardado 35 trials para el artifact 'eyem_musc'.
#
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=1846
#     Range : 0 ... 1845 =      0.000 ...     7.380 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 5 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 5 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 5 trials para 'elec'.
# Se han guardado 5 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaammu_s001_t001.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaammu_s001_t001.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaapas_s005_t000.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaapas_s005_t000.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=18834
#     Range : 0 ... 18833 =      0.000 ...    73.566 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 71 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 71 events and 768 original time points ...
# 0 bad epochs dropped
# Se encontraron 71 trials para 'musc'.
# Se han guardado 71 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaapas_s005_t000.edf.
# No se pudo extraer datos para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaapas_s005_t000.edf.
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=47303
#     Range : 0 ... 47302 =      0.000 ...   184.773 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 182 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 182 events and 768 original time points ...
# 0 bad epochs dropped
# Se encontraron 182 trials para 'elec'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaapas_s005_t000.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaapas_s005_t000.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaaprj_s002_t000.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaaprj_s002_t000.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaprj_s002_t000.edf.
# No se pudo extraer datos para el artifact 'musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaprj_s002_t000.edf.
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaprj_s002_t000.edf.
# No se pudo extraer datos para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaprj_s002_t000.edf.
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=18072
#     Range : 0 ... 18071 =      0.000 ...    70.590 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 68 events and 768 original time points ...
# 0 bad epochs dropped
# Se encontraron 68 trials para 'elec'.
# Se han guardado 68 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaprj_s002_t000.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaprj_s002_t000.edf.
#                                            path  label
# 0  ./scaleogram_output\label_2_elec\trial_0.npy      2
# 1  ./scaleogram_output\label_2_elec\trial_1.npy      2
# 2  ./scaleogram_output\label_2_elec\trial_2.npy      2
# 3  ./scaleogram_output\label_2_elec\trial_3.npy      2
# 4  ./scaleogram_output\label_2_elec\trial_4.npy      2
# EDF: v3.0.1/edf/01_tcp_ar/aaaaaijh_s002_t000.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaaijh_s002_t000.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=178510
#     Range : 0 ... 178509 =      0.000 ...   714.036 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 712 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 712 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 712 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=2694
#     Range : 0 ... 2693 =      0.000 ...    10.772 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 8 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 8 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 8 trials para 'eyem_musc'.
# Se han guardado 8 trials para el artifact 'eyem_musc'.
#
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=35986
#     Range : 0 ... 35985 =      0.000 ...   143.940 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 141 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 141 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 141 trials para 'elec'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaijh_s002_t000.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaijh_s002_t000.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaalco_s002_t000.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaalco_s002_t000.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=90934
#     Range : 0 ... 90933 =      0.000 ...   363.732 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 361 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 361 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 361 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=5064
#     Range : 0 ... 5063 =      0.000 ...    20.252 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 18 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 18 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 18 trials para 'eyem_musc'.
# Se han guardado 18 trials para el artifact 'eyem_musc'.
#
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=29644
#     Range : 0 ... 29643 =      0.000 ...   118.572 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 116 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 116 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 116 trials para 'elec'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaalco_s002_t000.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaalco_s002_t000.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaaphs_s001_t000.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaaphs_s001_t000.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=55458
#     Range : 0 ... 55457 =      0.000 ...   221.828 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 219 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 219 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 219 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=2648
#     Range : 0 ... 2647 =      0.000 ...    10.588 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 8 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 8 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 8 trials para 'eyem_musc'.
# Se han guardado 8 trials para el artifact 'eyem_musc'.
#
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=148616
#     Range : 0 ... 148615 =      0.000 ...   594.460 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 592 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 592 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 592 trials para 'elec'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaphs_s001_t000.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaphs_s001_t000.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaappv_s001_t001.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaappv_s001_t001.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=1112602
#     Range : 0 ... 1112601 =      0.000 ...  4450.404 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 4448 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 4448 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 4448 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=2230
#     Range : 0 ... 2229 =      0.000 ...     8.916 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 6 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 6 trials para 'eyem_musc'.
# Se han guardado 6 trials para el artifact 'eyem_musc'.
#
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=19081
#     Range : 0 ... 19080 =      0.000 ...    76.320 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 74 trials para 'elec'.
# Se han guardado 74 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaappv_s001_t001.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaappv_s001_t001.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaaarq_s004_t001.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaaarq_s004_t001.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=72765
#     Range : 0 ... 72764 =      0.000 ...   181.910 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 179 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 179 events and 1200 original time points ...
# 0 bad epochs dropped
# Se encontraron 179 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaarq_s004_t001.edf.
# No se pudo extraer datos para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaarq_s004_t001.edf.
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'elec' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaarq_s004_t001.edf.
# No se pudo extraer datos para el artifact 'elec' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaarq_s004_t001.edf.
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaarq_s004_t001.edf.
# No se pudo extraer datos para el artifact 'chew' en el archivo v3.0.1/edf/01_tcp_ar/aaaaaarq_s004_t001.edf.
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaajoo_s002_t001.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaajoo_s002_t001.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=593667
#     Range : 0 ... 593666 =      0.000 ...  2374.664 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 2372 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2372 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 2372 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=1036
#     Range : 0 ... 1035 =      0.000 ...     4.140 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 2 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 2 trials para 'eyem_musc'.
# Se han guardado 2 trials para el artifact 'eyem_musc'.
#
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=27649
#     Range : 0 ... 27648 =      0.000 ...   110.592 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 108 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 108 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 108 trials para 'elec'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=29652
#     Range : 0 ... 29651 =      0.000 ...   118.604 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 116 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 116 events and 750 original time points ...
# 0 bad epochs dropped
# Se encontraron 116 trials para 'chew'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'chew'.
#
#                                            path  label
# 0  ./scaleogram_output\label_0_musc\trial_0.npy      0
# 1  ./scaleogram_output\label_0_musc\trial_1.npy      0
# 2  ./scaleogram_output\label_0_musc\trial_2.npy      0
# 3  ./scaleogram_output\label_0_musc\trial_3.npy      0
# 4  ./scaleogram_output\label_0_musc\trial_4.npy      0
# EDF: v3.0.1/edf/01_tcp_ar/aaaaambs_s010_t006.edf, CSV: v3.0.1/edf/01_tcp_ar/aaaaambs_s010_t006.csv
# Procesando anotación: musc con etiqueta: 0
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=209535
#     Range : 0 ... 209534 =      0.000 ...   818.492 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 816 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 816 events and 768 original time points ...
# 0 bad epochs dropped
# Se encontraron 816 trials para 'musc'. Seleccionando los primeros 100.
# Se han guardado 100 trials para el artifact 'musc'.
#
# Procesando anotación: eyem_musc con etiqueta: 1
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# No se encontraron anotaciones para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaambs_s010_t006.edf.
# No se pudo extraer datos para el artifact 'eyem_musc' en el archivo v3.0.1/edf/01_tcp_ar/aaaaambs_s010_t006.edf.
# Procesando anotación: elec con etiqueta: 2
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=12997
#     Range : 0 ... 12996 =      0.000 ...    50.766 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 48 events and 768 original time points ...
# 0 bad epochs dropped
# Se encontraron 48 trials para 'elec'.
# Se han guardado 48 trials para el artifact 'elec'.
#
# Procesando anotación: chew con etiqueta: 3
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Creating RawArray with float64 data, n_channels=19, n_times=93340
#     Range : 0 ... 93339 =      0.000 ...   364.605 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 362 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 362 events and 768 original time points ...
# 0 bad epochs dropped
# Se encontraron 362 trials para 'chew'. Seleccionando los primeros 100.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 294
#     291         print("No se generaron scaleograms para ninguno de los archivos.")
#     293 if __name__ == "__main__":
# --> 294     main()
#
# Cell In[2], line 269, in main()
#     266 print(f"EDF: {edf_file}, CSV: {csv_file}")
#     268 # Procesar y guardar los scaleograms
# --> 269 df_scale = process_and_save_scaleograms(
#     270     edf_file,
#     271     csv_file,
#     272     artifacts,
#     273     output_dir='./scaleogram_output',
#     274     max_trials=100  # Limitar a 100 trials por artefacto
#     275 )
#     277 if df_scale is not None and not df_scale.empty:
#     278     all_scale_dfs.append(df_scale)
#
# Cell In[2], line 212, in process_and_save_scaleograms(edf_file, annotations_file, artifacts, output_dir, max_trials)
#     208 scaleograms = []
#     210 for channel_idx, channel_data in enumerate(trial_data):
#     211     # Aplicar CWT con la onda Morlet
# --> 212     Wx, scales = cwt(channel_data, 'morlet')  # Puedes ajustar 'scales' si lo deseas
#     213     Wx = np.abs(Wx)
#     214     scaleograms.append(Wx)
#
# File ~\anaconda3\envs\.ml_dl_eeg\lib\site-packages\ssqueezepy\_cwt.py:283, in cwt(x, wavelet, scales, fs, t, nv, l1_norm, derivative, padtype, rpadded, vectorized, astensor, cache_wavelet, order, average, nan_checks, patience)
#     281 # take CWT
#     282 if vectorized:
# --> 283     Wx, dWx = _vectorized(xh, scales, wavelet, derivative, cache_wavelet)
#     284 else:
#     285     Wx, dWx = _for_loop(xh, scales, wavelet, derivative, is_2D)
#
# File ~\anaconda3\envs\.ml_dl_eeg\lib\site-packages\ssqueezepy\_cwt.py:169, in cwt.<locals>._vectorized(xh, scales, wavelet, derivative, cache_wavelet)
#     167     Psih_xh = wavelet.Psih(scale=scales, nohalf=False) * xh
#     168 else:
# --> 169     Psih_xh = wavelet(scale=scales, nohalf=False) * xh
#     171 Wx = ifft(Psih_xh, axis=-1, astensor=True)
#     172 if derivative:
#
# File ~\anaconda3\envs\.ml_dl_eeg\lib\site-packages\ssqueezepy\wavelets.py:76, in Wavelet.__call__(self, w, scale, N, nohalf, imag_th)
#      74     psih = self.fn(S.asarray(w, self.dtype))
#      75 else:
# ---> 76     psih = self.fn(self.xifn(scale, N))
#      78 if not nohalf:
#      79     psih = self._halve_nyquist(psih)
#
# File ~\anaconda3\envs\.ml_dl_eeg\lib\site-packages\ssqueezepy\wavelets.py:129, in Wavelet.xifn(self, scale, N)
#     127 scale = S.asarray(scale, dtype=self.dtype)
#     128 if N is None:
# --> 129     xi = scale * self.xi
#     130 else:
#     131     xi = scale * S.asarray(_xifn(scale=1., N=N,
#     132                                  dtype=getattr(np, self.dtype)))
#
# KeyboardInterrupt:
